# %%
import numpy as np
import os
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import calendar

# %%
from mpl_toolkits.basemap import Basemap
import cartopy.crs as crs
import cartopy.feature as cfeature
import cartopy.io.shapereader as shpreader
import itertools

# %%
import matplotlib.patches as mpatches
from matplotlib.legend_handler import HandlerPatch
from mpl_toolkits.axes_grid1.inset_locator import zoomed_inset_axes
from mpl_toolkits.axes_grid1.inset_locator import mark_inset

# %%
fig = plt.figure(figsize=(12, 12))
m = Basemap(projection='cyl', resolution='l',
            llcrnrlat=33,urcrnrlat=68,\
            llcrnrlon=-15,urcrnrlon=35)
m.shadedrelief()

m.drawcountries()

# Map (long, lat) to (x, y) for plotting
x1, y1 = m(2.13, 41.39)
m.scatter(x1, y1, marker='o',color='yellow', s = 80, edgecolors='black')
plt.text(x1, y1, 'BCN', fontsize=12,
                    ha='left',va='top', color='black')

x2, y2 = m(-3, 40.42)
m.scatter(x2, y2, marker='o',color='yellow', s = 80, edgecolors='black')
plt.text(x2, y2, 'MAD', fontsize=12,
                    ha='left',va='top', color='black')

x3, y3 = m(-3.58, 37.18)
m.scatter(x3, y3, marker='o',color='yellow', s = 80, edgecolors='black')
plt.text(x3, y3, 'GRA', fontsize=12,
                    ha='left',va='top', color='black')

x4, y4 = m(24.95, 60.19)
m.scatter(x4, y4, marker='o',color='red', s = 80, edgecolors='black')
plt.text(x4, y4, 'HEL', fontsize=12,
                    ha='left',va='top', color='black')

x5, y5 = m(18.06, 59.33)
m.scatter(x5, y5, marker='o',color='red', s = 80, edgecolors='black')
plt.text(x5, y5, 'STO', fontsize=12,
                    ha='left',va='top', color='black')

x6, y6 = m(5.369780, 43.296482)
m.scatter(x6, y6, marker='o',color='yellow', s = 80, edgecolors='black')
plt.text(x6, y6, 'MAR', fontsize=12,
                    ha='left',va='top', color='black')

x7, y7 = m(23.719, 37.976)
m.scatter(x7, y7, marker='o',color='yellow', s = 80, edgecolors='black')
plt.text(x7, y7, 'ATH', fontsize=12,
                    ha='right',va='top', color='black')

x8, y8 = m(19.040236, 47.497913)
m.scatter(x8, y8, marker='o',color='yellow', s = 80, edgecolors='black')
plt.text(x8, y8, 'BUD', fontsize=12,
                    ha='left',va='top', color='black')

x9, y9 = m(-0.3, 51.52)
m.scatter(x9, y9, marker='o',color='yellow', s = 80, edgecolors='black')
plt.text(x9, y9, 'LND', fontsize=12,
                    ha='right',va='center', color='black')

x10, y10 = m(0.2, 51.1)
m.scatter(x10, y10, marker='o',color='yellow', s = 80, edgecolors='black')
plt.text(x10, y10, 'LND2', fontsize=12,
                    ha='center',va='top', color='black')

x11, y11 = m(8.6234, 47.40419)
m.scatter(x11, y11, marker='o',color='yellow', s = 80, edgecolors='black')
plt.text(x11, y11, 'ZUR', fontsize=12,
                    ha='left',va='top', color='black')

x12, y12 = m(12.73, 51.75)
m.scatter(x12, y12, marker='o',color='yellow', s = 80, edgecolors='black')
plt.text(x12, y12, 'LEI', fontsize=12,
                    ha='left',va='bottom', color='black')

x13, y13 = m(-1.898575, 52.489471)
m.scatter(x13, y13, marker='o',color='yellow', s = 80, edgecolors='black')
plt.text(x13, y13, 'BIR', fontsize=12,
                    ha='left',va='bottom', color='black')

x14, y14 = m(25.3807, 60.514)
m.scatter(x14, y14, marker='o',color='yellow', s = 80, edgecolors='black')
plt.text(x14, y14, 'HEL', fontsize=12,
                    ha='left',va='baseline', color='black')

x15, y15 = m(14.7631, 51.3872)
m.scatter(x15, y15, marker='o',color='red', s = 80, edgecolors='black')
plt.text(x15, y15, 'DRE', fontsize=12,
                    ha='left',va='bottom', color='black')

x16, y16 = m(12.18, 51.04)
m.scatter(x16, y16, marker='o',color='red', s = 80, edgecolors='black')
plt.text(x16, y16, 'LEI', fontsize=12,
                    ha='right',va='top', color='black')

x17, y17 = m(12.51, 51.35)
m.scatter(x17, y17, marker='o',color='red', s = 80, edgecolors='black')
plt.text(x17, y17, 'LEI2', fontsize=12,
                    ha='right',va='bottom', color='black')

x18, y18 = m(14.4520134, 50.0055707)
m.scatter(x18, y18, marker='o',color='deepskyblue', s = 80, edgecolors='black')
plt.text(x18, y18, 'PRA', fontsize=12,
                    ha='left',va='top', color='black')

x19, y19 = m(24.02, 38.29)
m.scatter(x19, y19, marker='o',color='deepskyblue', s = 80, edgecolors='black')
plt.text(x19, y19, 'ATH', fontsize=12,
                    ha='left',va='bottom', color='black')

x20, y20 = m(3.0667, 50.516694)
m.scatter(x20, y20, marker='o',color='deepskyblue', s = 80, edgecolors='black')
plt.text(x20, y20, 'LIL', fontsize=12,
                    ha='left',va='top', color='black')

x21, y21 = m(8.613056, 45.81472)
m.scatter(x21, y21, marker='o',color='limegreen', s = 80, edgecolors='black')
plt.text(x21, y21, 'ISP', fontsize=12,
                    ha='left',va='top', color='black')

x22, y22 = m(2.16, 48.71 )
m.scatter(x22, y22, marker='o',color='deepskyblue', s = 80, edgecolors='black')
plt.text(x22, y22, 'PAR', fontsize=12,
                    ha='right',va='top', color='black')

x23, y23 = m(8.39, 50 )
m.scatter(x23, y23, marker='o',color='yellow', s = 80, edgecolors='black')
plt.text(x23, y23, 'LAN', fontsize=12,
                    ha='left',va='top', color='black')

x24, y24 = m(14.5631, 51.0872)
m.scatter(x24, y24, marker='o',color='yellow', s = 80, edgecolors='black')
plt.text(x24, y24, 'DRE', fontsize=12,
                    ha='left',va='top', color='black')

x25, y25 = m(0.05, 51.65)
m.scatter(x25, y25, marker='o',color='red', s = 80, edgecolors='black')
plt.text(x25, y25, 'LND', fontsize=12,
                    ha='left',va='bottom', color='black')


colors = ["yellow", "red", "deepskyblue", "limegreen"]
texts = ["UB", "TR", "SUB", "RB"]
patches = [ plt.plot([],[], marker="o", ms=10, ls="", mec=None, color=colors[i], 
            label="{:s}".format(texts[i]) )[0]  for i in range(len(texts)) ]
plt.legend(handles=patches, 
           loc='center right', ncol=1, numpoints=1 )

roadPalette = {'UB': 'yellow',
               'TR': 'red',
               'SUB': 'cyan',
               'RB': 'limegreen'}

# %%
from matplotlib.colors import rgb2hex
from matplotlib.patches import Polygon

# %%
fig2 = plt.figure(figsize=(4, 4))
m = Basemap(projection='cyl', resolution='l',
            llcrnrlat=25,urcrnrlat=50,\
            llcrnrlon=-125,urcrnrlon=-65)

m.shadedrelief()

m.drawcountries()



#states = states.to_crs("EPSG:3395")
#states.boundary.plot()


x, y = m(-77.55, 43.15)
m.scatter(x, y, marker='o',color='yellow', s = 80, edgecolors='black')
plt.text(x, y, 'ROC', fontsize=12, 
         ha='left',va='top', color='black')
# Out:
# Text(-77.55, 43.15, 'ROC')

# %% [markdown]
# # MAPES AMB CONCENTRACIONS:

# %% [markdown]
# ### N10-800

# %%
fig = plt.figure(figsize=(12, 12))
m = Basemap(projection='cyl', resolution='l',
            llcrnrlat=33,urcrnrlat=68,\
            llcrnrlon=-15,urcrnrlon=35)
m.shadedrelief()

m.drawcountries()

# Map (long, lat) to (x, y) for plotting
#BCN
x1, y1 = m(2.13, 41.39)
m.scatter(x1, y1, marker='o',color='yellow', s = 80, edgecolors='black')
plt.text(x1, y1, '11.2', fontsize=12,
                    ha='left',va='top', color='black')
#MAD
x2, y2 = m(-3, 40.42)
m.scatter(x2, y2, marker='o',color='yellow', s = 80, edgecolors='black')
plt.text(x2, y2, '7.9', fontsize=12,
                    ha='left',va='top', color='black')
#GRA
x3, y3 = m(-3.58, 37.18)
m.scatter(x3, y3, marker='o',color='yellow', s = 80, edgecolors='black')
plt.text(x3, y3, '10.5', fontsize=12,
                    ha='left',va='top', color='black')
#HEL TR
x4, y4 = m(24.95, 60.19)
m.scatter(x4, y4, marker='o',color='red', s = 80, edgecolors='black')
plt.text(x4, y4, '10.5', fontsize=12,
                    ha='left',va='top', color='black')
#STO
x5, y5 = m(18.06, 59.33)
m.scatter(x5, y5, marker='o',color='red', s = 80, edgecolors='black')
plt.text(x5, y5, '5.1', fontsize=12,
                    ha='left',va='top', color='black')
#MAR
x6, y6 = m(5.369780, 43.296482)
m.scatter(x6, y6, marker='o',color='yellow', s = 80, edgecolors='black')
plt.text(x6, y6, '10.3', fontsize=12,
                    ha='left',va='top', color='black')
#ATH UB
x7, y7 = m(23.719, 37.976)
m.scatter(x7, y7, marker='o',color='yellow', s = 80, edgecolors='black')
plt.text(x7, y7, '8.6', fontsize=12,
                    ha='right',va='top', color='black')
#BUD
x8, y8 = m(19.040236, 47.497913)
m.scatter(x8, y8, marker='o',color='yellow', s = 80, edgecolors='black')
plt.text(x8, y8, '10.8', fontsize=12,
                    ha='left',va='top', color='black')
#LND UB
x9, y9 = m(-0.3, 51.52)
m.scatter(x9, y9, marker='o',color='yellow', s = 80, edgecolors='black')
plt.text(x9, y9, '4.5', fontsize=12,
                    ha='right',va='center', color='black')
#LND2 UB
x10, y10 = m(0.2, 51.1)
m.scatter(x10, y10, marker='o',color='yellow', s = 80, edgecolors='black')
plt.text(x10, y10, '4.4', fontsize=12,
                    ha='center',va='top', color='black')
#ZUR
x11, y11 = m(8.6234, 47.40419)
m.scatter(x11, y11, marker='o',color='yellow', s = 80, edgecolors='black')
plt.text(x11, y11, '4.2', fontsize=12,
                    ha='left',va='top', color='black')
#LEI UB
x12, y12 = m(12.73, 51.75)
m.scatter(x12, y12, marker='o',color='yellow', s = 80, edgecolors='black')
plt.text(x12, y12, '8.2', fontsize=12,
                    ha='left',va='bottom', color='black')
#BIR
x13, y13 = m(-1.898575, 52.489471)
m.scatter(x13, y13, marker='o',color='yellow', s = 80, edgecolors='black')
plt.text(x13, y13, '3.5', fontsize=12,
                    ha='left',va='bottom', color='black')
#HEL UB
x14, y14 = m(25.3807, 60.514)
m.scatter(x14, y14, marker='o',color='yellow', s = 80, edgecolors='black')
plt.text(x14, y14, '4.2', fontsize=12,
                    ha='left',va='baseline', color='black')
#DRE TR
x15, y15 = m(14.7631, 51.3872)
m.scatter(x15, y15, marker='o',color='red', s = 80, edgecolors='black')
plt.text(x15, y15, '8.8', fontsize=12,
                    ha='left',va='bottom', color='black')
#LEI TR
x16, y16 = m(12.18, 51.04)
m.scatter(x16, y16, marker='o',color='red', s = 80, edgecolors='black')
plt.text(x16, y16, '13.6', fontsize=12,
                    ha='right',va='top', color='black')
#LEI2 TR
x17, y17 = m(12.51, 51.35)
m.scatter(x17, y17, marker='o',color='red', s = 80, edgecolors='black')
plt.text(x17, y17, '12.0', fontsize=12,
                    ha='right',va='bottom', color='black')
#PRA
x18, y18 = m(14.4520134, 50.0055707)
m.scatter(x18, y18, marker='o',color='deepskyblue', s = 80, edgecolors='black')
plt.text(x18, y18, '7.9', fontsize=12,
                    ha='left',va='top', color='black')
#ATH SUB
x19, y19 = m(24.02, 38.29)
m.scatter(x19, y19, marker='o',color='deepskyblue', s = 80, edgecolors='black')
plt.text(x19, y19, '6.1', fontsize=12,
                    ha='left',va='bottom', color='black')
#LIL
x20, y20 = m(3.0667, 50.516694)
m.scatter(x20, y20, marker='o',color='deepskyblue', s = 80, edgecolors='black')
plt.text(x20, y20, '6.1', fontsize=12,
                    ha='left',va='top', color='black')
#ISP
x21, y21 = m(8.613056, 45.81472)
m.scatter(x21, y21, marker='o',color='limegreen', s = 80, edgecolors='black')
plt.text(x21, y21, '7.4', fontsize=12,
                    ha='left',va='top', color='black')
#PAR
x22, y22 = m(2.16, 48.71 )
m.scatter(x22, y22, marker='o',color='deepskyblue', s = 80, edgecolors='black')
plt.text(x22, y22, '4.5', fontsize=12,
                    ha='right',va='top', color='black')
#LAN
x23, y23 = m(8.39, 50 )
m.scatter(x23, y23, marker='o',color='yellow', s = 80, edgecolors='black')
plt.text(x23, y23, '10.0', fontsize=12,
                    ha='left',va='top', color='black')
#DRE UB
x24, y24 = m(14.5631, 51.0872)
m.scatter(x24, y24, marker='o',color='yellow', s = 80, edgecolors='black')
plt.text(x24, y24, '6.2', fontsize=12,
                    ha='left',va='top', color='black')
#LND TR
x25, y25 = m(0.05, 51.65)
m.scatter(x25, y25, marker='o',color='red', s = 80, edgecolors='black')
plt.text(x25, y25, '10.6', fontsize=12,
                    ha='left',va='bottom', color='black')


colors = ["yellow", "red", "deepskyblue", "limegreen"]
texts = ["UB", "TR", "SUB", "RB"]
patches = [ plt.plot([],[], marker="o", ms=10, ls="", mec=None, color=colors[i], 
            label="{:s}".format(texts[i]) )[0]  for i in range(len(texts)) ]
plt.legend(handles=patches, 
           loc='center right', ncol=1, numpoints=1 )

roadPalette = {'UB': 'yellow',
               'TR': 'red',
               'SUB': 'cyan',
               'RB': 'limegreen'}

# %%
#ROC
fig2 = plt.figure(figsize=(4, 4))
m = Basemap(projection='cyl', resolution='l',
            llcrnrlat=25,urcrnrlat=50,\
            llcrnrlon=-125,urcrnrlon=-65)

m.shadedrelief()

m.drawcountries()



#states = states.to_crs("EPSG:3395")
#states.boundary.plot()


x, y = m(-77.55, 43.15)
m.scatter(x, y, marker='o',color='yellow', s = 80, edgecolors='black')
plt.text(x, y, '4.4', fontsize=12, 
         ha='left',va='top', color='black')
# Out:
# Text(-77.55, 43.15, '4.4')

# %% [markdown]
# ### N25-800

# %%
fig = plt.figure(figsize=(12, 12))
m = Basemap(projection='cyl', resolution='l',
            llcrnrlat=33,urcrnrlat=68,\
            llcrnrlon=-15,urcrnrlon=35)
m.shadedrelief()

m.drawcountries()

# Map (long, lat) to (x, y) for plotting
#BCN
x1, y1 = m(2.13, 41.39)
m.scatter(x1, y1, marker='o',color='yellow', s = 80, edgecolors='black')
plt.text(x1, y1, '6.9', fontsize=12,
                    ha='left',va='top', color='black')
#MAD
x2, y2 = m(-3, 40.42)
m.scatter(x2, y2, marker='o',color='yellow', s = 80, edgecolors='black')
plt.text(x2, y2, '5.9', fontsize=12,
                    ha='left',va='top', color='black')
#GRA
x3, y3 = m(-3.58, 37.18)
m.scatter(x3, y3, marker='o',color='yellow', s = 80, edgecolors='black')
plt.text(x3, y3, '7.4', fontsize=12,
                    ha='left',va='top', color='black')
#HEL TR
x4, y4 = m(24.95, 60.19)
m.scatter(x4, y4, marker='o',color='red', s = 80, edgecolors='black')
plt.text(x4, y4, '4.4', fontsize=12,
                    ha='left',va='top', color='black')
#STO
x5, y5 = m(18.06, 59.33)
m.scatter(x5, y5, marker='o',color='red', s = 80, edgecolors='black')
plt.text(x5, y5, '3.4', fontsize=12,
                    ha='left',va='top', color='black')
#MAR
x6, y6 = m(5.369780, 43.296482)
m.scatter(x6, y6, marker='o',color='yellow', s = 80, edgecolors='black')
plt.text(x6, y6, '7.6', fontsize=12,
                    ha='left',va='top', color='black')
#ATH UB
x7, y7 = m(23.719, 37.976)
m.scatter(x7, y7, marker='o',color='yellow', s = 80, edgecolors='black')
plt.text(x7, y7, '7.0', fontsize=12,
                    ha='right',va='top', color='black')
#BUD
x8, y8 = m(19.040236, 47.497913)
m.scatter(x8, y8, marker='o',color='yellow', s = 80, edgecolors='black')
plt.text(x8, y8, '7.1', fontsize=12,
                    ha='left',va='top', color='black')
#LND UB
x9, y9 = m(-0.3, 51.52)
m.scatter(x9, y9, marker='o',color='yellow', s = 80, edgecolors='black')
plt.text(x9, y9, '3.9', fontsize=12,
                    ha='right',va='center', color='black')
#LND2 UB
x10, y10 = m(0.2, 51.1)
m.scatter(x10, y10, marker='o',color='yellow', s = 80, edgecolors='black')
plt.text(x10, y10, '3.9', fontsize=12,
                    ha='center',va='top', color='black')
#ZUR
x11, y11 = m(8.6234, 47.40419)
m.scatter(x11, y11, marker='o',color='yellow', s = 80, edgecolors='black')
plt.text(x11, y11, '3.9', fontsize=12,
                    ha='left',va='top', color='black')
#LEI UB
x12, y12 = m(12.73, 51.75)
m.scatter(x12, y12, marker='o',color='yellow', s = 80, edgecolors='black')
plt.text(x12, y12, '4.9', fontsize=12,
                    ha='left',va='bottom', color='black')
#BIR
x13, y13 = m(-1.898575, 52.489471)
m.scatter(x13, y13, marker='o',color='yellow', s = 80, edgecolors='black')
plt.text(x13, y13, '2.9', fontsize=12,
                    ha='left',va='bottom', color='black')
#HEL UB
x14, y14 = m(25.3807, 60.514)
m.scatter(x14, y14, marker='o',color='yellow', s = 80, edgecolors='black')
plt.text(x14, y14, '2.8', fontsize=12,
                    ha='left',va='baseline', color='black')
#DRE TR
x15, y15 = m(14.7631, 51.3872)
m.scatter(x15, y15, marker='o',color='red', s = 80, edgecolors='black')
plt.text(x15, y15, '5.1', fontsize=12,
                    ha='left',va='bottom', color='black')
#LEI TR
x16, y16 = m(12.18, 51.04)
m.scatter(x16, y16, marker='o',color='red', s = 80, edgecolors='black')
plt.text(x16, y16, '6.9', fontsize=12,
                    ha='right',va='top', color='black')
#LEI2 TR
x17, y17 = m(12.51, 51.35)
m.scatter(x17, y17, marker='o',color='red', s = 80, edgecolors='black')
plt.text(x17, y17, '6.8', fontsize=12,
                    ha='right',va='bottom', color='black')
#PRA
x18, y18 = m(14.4520134, 50.0055707)
m.scatter(x18, y18, marker='o',color='deepskyblue', s = 80, edgecolors='black')
plt.text(x18, y18, '5.4', fontsize=12,
                    ha='left',va='top', color='black')
#ATH SUB
x19, y19 = m(24.02, 38.29)
m.scatter(x19, y19, marker='o',color='deepskyblue', s = 80, edgecolors='black')
plt.text(x19, y19, '4.4', fontsize=12,
                    ha='left',va='bottom', color='black')
#LIL
x20, y20 = m(3.0667, 50.516694)
m.scatter(x20, y20, marker='o',color='deepskyblue', s = 80, edgecolors='black')
plt.text(x20, y20, '5.6', fontsize=12,
                    ha='left',va='top', color='black')
#ISP
x21, y21 = m(8.613056, 45.81472)
m.scatter(x21, y21, marker='o',color='limegreen', s = 80, edgecolors='black')
plt.text(x21, y21, '6.4', fontsize=12,
                    ha='left',va='top', color='black')
#PAR
x22, y22 = m(2.16, 48.71 )
m.scatter(x22, y22, marker='o',color='deepskyblue', s = 80, edgecolors='black')
plt.text(x22, y22, '3.4', fontsize=12,
                    ha='right',va='top', color='black')
#LAN
x23, y23 = m(8.39, 50 )
m.scatter(x23, y23, marker='o',color='yellow', s = 80, edgecolors='black')
plt.text(x23, y23, '5.3', fontsize=12,
                    ha='left',va='top', color='black')
#DRE UB
x24, y24 = m(14.5631, 51.0872)
m.scatter(x24, y24, marker='o',color='yellow', s = 80, edgecolors='black')
plt.text(x24, y24, '4.3', fontsize=12,
                    ha='left',va='top', color='black')
#LND TR
x25, y25 = m(0.05, 51.65)
m.scatter(x25, y25, marker='o',color='red', s = 80, edgecolors='black')
plt.text(x25, y25, '8.7', fontsize=12,
                    ha='left',va='bottom', color='black')


colors = ["yellow", "red", "deepskyblue", "limegreen"]
texts = ["UB", "TR", "SUB", "RB"]
patches = [ plt.plot([],[], marker="o", ms=10, ls="", mec=None, color=colors[i], 
            label="{:s}".format(texts[i]) )[0]  for i in range(len(texts)) ]
plt.legend(handles=patches, 
           loc='center right', ncol=1, numpoints=1 )

roadPalette = {'UB': 'yellow',
               'TR': 'red',
               'SUB': 'cyan',
               'RB': 'limegreen'}

# %%
#ROC
fig2 = plt.figure(figsize=(4, 4))
m = Basemap(projection='cyl', resolution='l',
            llcrnrlat=25,urcrnrlat=50,\
            llcrnrlon=-125,urcrnrlon=-65)

m.shadedrelief()

m.drawcountries()



#states = states.to_crs("EPSG:3395")
#states.boundary.plot()


x, y = m(-77.55, 43.15)
m.scatter(x, y, marker='o',color='yellow', s = 80, edgecolors='black')
plt.text(x, y, '3.0', fontsize=12, 
         ha='left',va='top', color='black')
# Out:
# Text(-77.55, 43.15, '3.0')

# %% [markdown]
# ### BC

# %%
fig = plt.figure(figsize=(12, 12))
m = Basemap(projection='cyl', resolution='l',
            llcrnrlat=33,urcrnrlat=68,\
            llcrnrlon=-15,urcrnrlon=35)
m.shadedrelief()

m.drawcountries()

# Map (long, lat) to (x, y) for plotting
#BCN
x1, y1 = m(2.13, 41.39)
m.scatter(x1, y1, marker='o',color='yellow', s = 80, edgecolors='black')
plt.text(x1, y1, '6.9', fontsize=12,
                    ha='left',va='top', color='black')
#MAD
x2, y2 = m(-3, 40.42)
m.scatter(x2, y2, marker='o',color='yellow', s = 80, edgecolors='black')
plt.text(x2, y2, '5.9', fontsize=12,
                    ha='left',va='top', color='black')
#GRA
x3, y3 = m(-3.58, 37.18)
m.scatter(x3, y3, marker='o',color='yellow', s = 80, edgecolors='black')
plt.text(x3, y3, '7.4', fontsize=12,
                    ha='left',va='top', color='black')
#HEL TR
x4, y4 = m(24.95, 60.19)
m.scatter(x4, y4, marker='o',color='red', s = 80, edgecolors='black')
plt.text(x4, y4, '4.4', fontsize=12,
                    ha='left',va='top', color='black')
#STO
x5, y5 = m(18.06, 59.33)
m.scatter(x5, y5, marker='o',color='red', s = 80, edgecolors='black')
plt.text(x5, y5, '3.4', fontsize=12,
                    ha='left',va='top', color='black')
#MAR
x6, y6 = m(5.369780, 43.296482)
m.scatter(x6, y6, marker='o',color='yellow', s = 80, edgecolors='black')
plt.text(x6, y6, '7.6', fontsize=12,
                    ha='left',va='top', color='black')
#ATH UB
x7, y7 = m(23.719, 37.976)
m.scatter(x7, y7, marker='o',color='yellow', s = 80, edgecolors='black')
plt.text(x7, y7, '7.0', fontsize=12,
                    ha='right',va='top', color='black')
#BUD
x8, y8 = m(19.040236, 47.497913)
m.scatter(x8, y8, marker='o',color='yellow', s = 80, edgecolors='black')
plt.text(x8, y8, '7.1', fontsize=12,
                    ha='left',va='top', color='black')
#LND UB
x9, y9 = m(-0.3, 51.52)
m.scatter(x9, y9, marker='o',color='yellow', s = 80, edgecolors='black')
plt.text(x9, y9, '3.9', fontsize=12,
                    ha='right',va='center', color='black')
#LND2 UB
x10, y10 = m(0.2, 51.1)
m.scatter(x10, y10, marker='o',color='yellow', s = 80, edgecolors='black')
plt.text(x10, y10, '3.9', fontsize=12,
                    ha='center',va='top', color='black')
#ZUR
x11, y11 = m(8.6234, 47.40419)
m.scatter(x11, y11, marker='o',color='yellow', s = 80, edgecolors='black')
plt.text(x11, y11, '3.9', fontsize=12,
                    ha='left',va='top', color='black')
#LEI UB
x12, y12 = m(12.73, 51.75)
m.scatter(x12, y12, marker='o',color='yellow', s = 80, edgecolors='black')
plt.text(x12, y12, '4.9', fontsize=12,
                    ha='left',va='bottom', color='black')
#BIR
x13, y13 = m(-1.898575, 52.489471)
m.scatter(x13, y13, marker='o',color='yellow', s = 80, edgecolors='black')
plt.text(x13, y13, '2.9', fontsize=12,
                    ha='left',va='bottom', color='black')
#HEL UB
x14, y14 = m(25.3807, 60.514)
m.scatter(x14, y14, marker='o',color='yellow', s = 80, edgecolors='black')
plt.text(x14, y14, '2.8', fontsize=12,
                    ha='left',va='baseline', color='black')
#DRE TR
x15, y15 = m(14.7631, 51.3872)
m.scatter(x15, y15, marker='o',color='red', s = 80, edgecolors='black')
plt.text(x15, y15, '5.1', fontsize=12,
                    ha='left',va='bottom', color='black')
#LEI TR
x16, y16 = m(12.18, 51.04)
m.scatter(x16, y16, marker='o',color='red', s = 80, edgecolors='black')
plt.text(x16, y16, '6.9', fontsize=12,
                    ha='right',va='top', color='black')
#LEI2 TR
x17, y17 = m(12.51, 51.35)
m.scatter(x17, y17, marker='o',color='red', s = 80, edgecolors='black')
plt.text(x17, y17, '6.8', fontsize=12,
                    ha='right',va='bottom', color='black')
#PRA
x18, y18 = m(14.4520134, 50.0055707)
m.scatter(x18, y18, marker='o',color='deepskyblue', s = 80, edgecolors='black')
plt.text(x18, y18, '5.4', fontsize=12,
                    ha='left',va='top', color='black')
#ATH SUB
x19, y19 = m(24.02, 38.29)
m.scatter(x19, y19, marker='o',color='deepskyblue', s = 80, edgecolors='black')
plt.text(x19, y19, '4.4', fontsize=12,
                    ha='left',va='bottom', color='black')
#LIL
x20, y20 = m(3.0667, 50.516694)
m.scatter(x20, y20, marker='o',color='deepskyblue', s = 80, edgecolors='black')
plt.text(x20, y20, '5.6', fontsize=12,
                    ha='left',va='top', color='black')
#ISP
x21, y21 = m(8.613056, 45.81472)
m.scatter(x21, y21, marker='o',color='limegreen', s = 80, edgecolors='black')
plt.text(x21, y21, '6.4', fontsize=12,
                    ha='left',va='top', color='black')
#PAR
x22, y22 = m(2.16, 48.71 )
m.scatter(x22, y22, marker='o',color='deepskyblue', s = 80, edgecolors='black')
plt.text(x22, y22, '3.4', fontsize=12,
                    ha='right',va='top', color='black')
#LAN
x23, y23 = m(8.39, 50 )
m.scatter(x23, y23, marker='o',color='yellow', s = 80, edgecolors='black')
plt.text(x23, y23, '5.3', fontsize=12,
                    ha='left',va='top', color='black')
#DRE UB
x24, y24 = m(14.5631, 51.0872)
m.scatter(x24, y24, marker='o',color='yellow', s = 80, edgecolors='black')
plt.text(x24, y24, '4.3', fontsize=12,
                    ha='left',va='top', color='black')
#LND TR
x25, y25 = m(0.05, 51.65)
m.scatter(x25, y25, marker='o',color='red', s = 80, edgecolors='black')
plt.text(x25, y25, '8.7', fontsize=12,
                    ha='left',va='bottom', color='black')


colors = ["yellow", "red", "deepskyblue", "limegreen"]
texts = ["UB", "TR", "SUB", "RB"]
patches = [ plt.plot([],[], marker="o", ms=10, ls="", mec=None, color=colors[i], 
            label="{:s}".format(texts[i]) )[0]  for i in range(len(texts)) ]
plt.legend(handles=patches, 
           loc='center right', ncol=1, numpoints=1 )

roadPalette = {'UB': 'yellow',
               'TR': 'red',
               'SUB': 'cyan',
               'RB': 'limegreen'}
